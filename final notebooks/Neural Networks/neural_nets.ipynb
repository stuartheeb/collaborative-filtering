# %% [markdown]
# # Neural Network for Collaborative Filtering

# %%
from numpy.random import seed
seed(42)

# %tensorflow_version 2.x
import tensorflow as tf
tf.random.set_seed(42)

# %%
# !pip install kaggle

# !mkdir ~/.kaggle

import json

kaggle_username = "yuvalnis" #@param {type:"string"}
kaggle_api_key = "1800d5a286834f0416c338c7bd7f6dee" #@param {type:"string"}

assert len(kaggle_username) > 0 and len(kaggle_api_key) > 0

api_token = {"username": kaggle_username,"key": kaggle_api_key}

with open('kaggle.json', 'w') as file:
    json.dump(api_token, file)

# !mv kaggle.json ~/.kaggle/kaggle.json

# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c cil-collaborative-filtering-2022

# !unzip -n cil-collaborative-filtering-2022.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.6.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Downloading cil-collaborative-filtering-2022.zip to /content
#  80% 5.00M/6.25M [00:00<00:00, 10.9MB/s]
# 100% 6.25M/6.25M [00:00<00:00, 13.5MB/s]
# Archive:  cil-collaborative-filtering-2022.zip
#   inflating: data_train.csv
#   inflating: sampleSubmission.csv

# %%
# !pip install --upgrade keras-hypetune
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-hypetune
#   Downloading keras_hypetune-0.2.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-hypetune) (1.21.6)
# Collecting hyperopt==0.2.5
#   Downloading hyperopt-0.2.5-py2.py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 12.0 MB/s
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (2.6.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (4.64.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (1.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (1.7.3)
# Installing collected packages: hyperopt, keras-hypetune
#   Attempting uninstall: hyperopt
#     Found existing installation: hyperopt 0.1.2
#     Uninstalling hyperopt-0.1.2:
#       Successfully uninstalled hyperopt-0.1.2
# Successfully installed hyperopt-0.2.5 keras-hypetune-0.2.1

# %% [markdown]
# ## Imports

# %%
import math

import pandas as pd
import numpy as np

from keras.layers import Input, Embedding, Reshape, Dot, Concatenate, Dense, Dropout, Flatten, Lambda
from keras.models import Model

from keras.callbacks import *

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

from kerashypetune import *

# %%
print('TF VERSION = ' + str(tf.__version__))
# Out:
# TF VERSION = 2.8.2

# %% [markdown]
# ## Functions

# %%
def extract_users_items_predictions(data_pd):
        users, movies = \
            [np.squeeze(arr) for arr in np.split(data_pd.Id.str.extract('r(\d+)_c(\d+)').values.astype(int) - 1, 2, axis=-1)]
        predictions = data_pd.Prediction.values
        return users, movies, predictions

def submission_from_separate_predictions(sub_pd, sub_pred, sub_user_data, sub_movie_data, filename):
  temp_pd = sub_pd.copy()
  Id = []
  pred = []
  for i in range(sub_pred.shape[0]):
    Id.append("r"+str(sub_user_data[i]+1)+"_c"+str(sub_movie_data[i]+1))
    pred.append(sub_pred[i,0])
  temp_pd['Prediction'] = pred
  temp_pd.set_index("Id", inplace = True)
  print(temp_pd.sample(3)) 
  temp_pd.to_csv(str(filename) + '.csv')

# %% [markdown]
# ## Input

# %%
data_pd = pd.read_csv('data_train.csv')
tmp_users, tmp_movies, tmp_predictions = extract_users_items_predictions(data_pd)

d = {'User': tmp_users, 'Rating': tmp_predictions, 'Movie': tmp_movies}
df = pd.DataFrame(data=d)

del tmp_users, tmp_movies, tmp_predictions

df.sample(3)
# Out:
#         User  Rating  Movie
# 904556  5061       2    705
# 171326  9043       4    147
# 190893  1735       4    168

# %%
sub_pd = pd.read_csv('sampleSubmission.csv')#,index_col='Id')
tmp_users, tmp_movies, tmp_predictions = extract_users_items_predictions(sub_pd)

d = {'User': tmp_users, 'Rating': tmp_predictions, 'Movie': tmp_movies}
df_sub = pd.DataFrame(data=d)

del tmp_users, tmp_movies, tmp_predictions

df_sub.sample(3)
# Out:
#          User  Rating  Movie
# 1158113  8460       3    981
# 1095471    30       3    897
# 478282   8580       3    410

# %% [markdown]
# ## Pre-processing

# %%
df = df.reset_index(drop=True)

user_id_mapping = {id:i for i, id in enumerate(df['User'].unique())}
movie_id_mapping = {id:i for i, id in enumerate(df['Movie'].unique())}

users = len(user_id_mapping)
movies = len(movie_id_mapping)

print("Number of users: " + str(users))
print("Number of movies: " + str(movies))

user_data = df['User'].to_numpy()
movie_data = df['Movie'].to_numpy()
ratings_data = df[['Rating']].to_numpy()

X = np.stack([user_data, movie_data], axis=-1)
y = ratings_data
# Out:
# Number of users: 10000
# Number of movies: 1000

# %%
sub_user_data = df_sub['User'].to_numpy()
sub_movie_data = df_sub['Movie'].to_numpy()

X_sub = np.stack([sub_user_data, sub_movie_data], axis=-1)

# %% [markdown]
# ### Train-test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, random_state=42)

print("X shape: " + str(X.shape))
print("y shape: " + str(y.shape))

print("X_train shape: " + str(X_train.shape))
print("X_test shape: " + str(X_test.shape))

print("y_train shape: " + str(y_train.shape))
print("y_test shape: " + str(y_test.shape))
# Out:
# X shape: (1176952, 2)
# y shape: (1176952, 1)
# X_train shape: (1059256, 2)
# X_test shape: (117696, 2)
# y_train shape: (1059256, 1)
# y_test shape: (117696, 1)

# %% [markdown]
# ## Model

# %%
def get_model(param):
    combined_input = Input((2,))

    user_id_input = Lambda(lambda x: tf.expand_dims(x[:,0],-1))(combined_input)
    u = Embedding(input_dim=users, output_dim=param['user_embedding_size'])(user_id_input)
    u = Flatten()(u)

    movie_id_input = Lambda(lambda x: tf.expand_dims(x[:,1],-1))(combined_input)
    i = Embedding(input_dim=movies, output_dim=param['movie_embedding_size'])(movie_id_input)
    i = Flatten()(i)

    x = Concatenate(name="concatenated_vector")([i, u])

    for n in [1, 2, 4]:
      x = Dense(units=param['max_units']/n, activation=param['activation'])(x)
      x = Dropout(0.1)(x)

    x = Dense(units=100, activation="relu")(x)
    y = Dense(units=1)(x)


    model = Model(inputs=combined_input, outputs=y)
    model.compile(
        loss='mean_squared_error',
        optimizer=tf.keras.optimizers.Adam(learning_rate=param['lr']),
        metrics=[tf.keras.metrics.RootMeanSquaredError()],
    )
    
    return model

# %% [markdown]
# ## Grid Search

# %% [markdown]
# ### Define grid

# %%
param_grid = {
    'user_embedding_size' : [40, 80, 120],
    'movie_embedding_size' : [40, 80, 120],
    'max_units' : [800, 1200],
    'lr' : [1e-2, 1e-3, 1e-4],
    'epochs' : [100],
    'batch_size': [128,256],
    'activation' : ["relu", "sigmoid"]
}

# %% [markdown]
# ### Perform grid search

# %%
kgs = KerasGridSearch(get_model, param_grid, monitor='val_loss', store_model=True, greater_is_better=False, tuner_verbose=1)

# %%
es = EarlyStopping(patience=5, verbose=1, min_delta=0.001, monitor='val_loss', mode='auto', restore_best_weights=True)

# %%
kgs.search(X_train, y_train,
           validation_data = (X_test, y_test),
           callbacks=[es])
# Out:
# 216 trials detected for ('user_embedding_size', 'movie_embedding_size', 'max_units', 'lr', 'epochs', 'batch_size', 'activation')
#
# ***** (1/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00862 at epoch 4
#
# ***** (2/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00178 at epoch 3
#
# ***** (3/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00689 at epoch 4
#
# ***** (4/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00409 at epoch 5
#
# ***** (5/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 11.
# Epoch 16: early stopping
# SCORE: 1.05635 at epoch 11
#
# ***** (6/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.2541 at epoch 1
#
# ***** (7/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.25442 at epoch 8
#
# ***** (8/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.06613 at epoch 3
#
# ***** (9/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 0.99437 at epoch 9
#
# ***** (10/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99006 at epoch 3
#
# ***** (11/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99588 at epoch 6
#
# ***** (12/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99498 at epoch 3
#
# ***** (13/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00041 at epoch 3
#
# ***** (14/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00359 at epoch 3
#
# ***** (15/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00169 at epoch 4
#
# ***** (16/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00485 at epoch 3
#
# ***** (17/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25441 at epoch 2
#
# ***** (18/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25446 at epoch 1
#
# ***** (19/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25443 at epoch 5
#
# ***** (20/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.08659 at epoch 1
#
# ***** (21/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 0.99376 at epoch 9
#
# ***** (22/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99526 at epoch 3
#
# ***** (23/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99514 at epoch 6
#
# ***** (24/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00163 at epoch 3
#
# ***** (25/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00541 at epoch 4
#
# ***** (26/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00307 at epoch 3
#
# ***** (27/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.01436 at epoch 4
#
# ***** (28/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00328 at epoch 3
#
# ***** (29/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# SCORE: 1.048 at epoch 7
#
# ***** (30/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.16826 at epoch 3
#
# ***** (31/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.25442 at epoch 8
#
# ***** (32/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.15866 at epoch 1
#
# ***** (33/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99496 at epoch 5
#
# ***** (34/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99672 at epoch 3
#
# ***** (35/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 0.99616 at epoch 6
#
# ***** (36/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99704 at epoch 3
#
# ***** (37/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00084 at epoch 4
#
# ***** (38/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00516 at epoch 3
#
# ***** (39/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.0039 at epoch 4
#
# ***** (40/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.0048 at epoch 3
#
# ***** (41/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25441 at epoch 2
#
# ***** (42/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25469 at epoch 1
#
# ***** (43/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25443 at epoch 5
#
# ***** (44/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.09235 at epoch 1
#
# ***** (45/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 0.99334 at epoch 9
#
# ***** (46/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99227 at epoch 3
#
# ***** (47/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 8.
# Epoch 13: early stopping
# SCORE: 0.99417 at epoch 8
#
# ***** (48/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99557 at epoch 3
#
# ***** (49/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00133 at epoch 4
#
# ***** (50/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00166 at epoch 4
#
# ***** (51/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00535 at epoch 4
#
# ***** (52/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00474 at epoch 4
#
# ***** (53/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 1.03534 at epoch 9
#
# ***** (54/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25445 at epoch 5
#
# ***** (55/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 16.
# Epoch 21: early stopping
# SCORE: 1.04455 at epoch 16
#
# ***** (56/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.22984 at epoch 2
#
# ***** (57/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 0.99389 at epoch 9
#
# ***** (58/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99318 at epoch 3
#
# ***** (59/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99489 at epoch 6
#
# ***** (60/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99149 at epoch 3
#
# ***** (61/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00089 at epoch 3
#
# ***** (62/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00114 at epoch 3
#
# ***** (63/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00234 at epoch 4
#
# ***** (64/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.0051 at epoch 3
#
# ***** (65/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.2544 at epoch 2
#
# ***** (66/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.22965 at epoch 1
#
# ***** (67/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 1.25442 at epoch 8
#
# ***** (68/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.19906 at epoch 2
#
# ***** (69/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 0.99476 at epoch 9
#
# ***** (70/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99465 at epoch 4
#
# ***** (71/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99467 at epoch 6
#
# ***** (72/216) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99499 at epoch 3
#
# ***** (73/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00066 at epoch 4
#
# ***** (74/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99911 at epoch 3
#
# ***** (75/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00172 at epoch 4
#
# ***** (76/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00321 at epoch 3
#
# ***** (77/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.2544 at epoch 2
#
# ***** (78/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.21689 at epoch 1
#
# ***** (79/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 1.02132 at epoch 6
#
# ***** (80/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.1004 at epoch 1
#
# ***** (81/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 0.9936 at epoch 9
#
# ***** (82/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.9946 at epoch 5
#
# ***** (83/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99642 at epoch 6
#
# ***** (84/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99816 at epoch 3
#
# ***** (85/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.0008 at epoch 3
#
# ***** (86/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00333 at epoch 3
#
# ***** (87/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00127 at epoch 3
#
# ***** (88/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00172 at epoch 3
#
# ***** (89/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.2544 at epoch 2
#
# ***** (90/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 8.
# Epoch 13: early stopping
# SCORE: 1.18843 at epoch 8
#
# ***** (91/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25443 at epoch 5
#
# ***** (92/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 1.19555 at epoch 8
#
# ***** (93/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99476 at epoch 9
#
# ***** (94/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99363 at epoch 5
#
# ***** (95/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99584 at epoch 6
#
# ***** (96/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.9985 at epoch 3
#
# ***** (97/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.01594 at epoch 4
#
# ***** (98/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99969 at epoch 3
#
# ***** (99/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00807 at epoch 4
#
# ***** (100/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00287 at epoch 3
#
# ***** (101/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 1.04165 at epoch 7
#
# ***** (102/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25467 at epoch 1
#
# ***** (103/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 1.03438 at epoch 9
#
# ***** (104/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25456 at epoch 2
#
# ***** (105/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 0.99494 at epoch 9
#
# ***** (106/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99127 at epoch 3
#
# ***** (107/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.9963 at epoch 6
#
# ***** (108/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.9908 at epoch 3
#
# ***** (109/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.0007 at epoch 3
#
# ***** (110/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00364 at epoch 3
#
# ***** (111/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00188 at epoch 4
#
# ***** (112/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00448 at epoch 3
#
# ***** (113/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.2544 at epoch 2
#
# ***** (114/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.18955 at epoch 1
#
# ***** (115/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.18324 at epoch 2
#
# ***** (116/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.11875 at epoch 2
#
# ***** (117/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99495 at epoch 9
#
# ***** (118/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99571 at epoch 3
#
# ***** (119/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99452 at epoch 6
#
# ***** (120/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99683 at epoch 3
#
# ***** (121/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00155 at epoch 4
#
# ***** (122/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00353 at epoch 3
#
# ***** (123/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.00812 at epoch 2
#
# ***** (124/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00426 at epoch 4
#
# ***** (125/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# SCORE: 1.04348 at epoch 7
#
# ***** (126/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25451 at epoch 5
#
# ***** (127/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 8.
# Epoch 13: early stopping
# SCORE: 1.0402 at epoch 12
#
# ***** (128/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.09527 at epoch 1
#
# ***** (129/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 0.9962 at epoch 7
#
# ***** (130/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99222 at epoch 3
#
# ***** (131/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 0.99706 at epoch 7
#
# ***** (132/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.997 at epoch 3
#
# ***** (133/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00127 at epoch 4
#
# ***** (134/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00278 at epoch 3
#
# ***** (135/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.0041 at epoch 4
#
# ***** (136/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00396 at epoch 3
#
# ***** (137/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25441 at epoch 2
#
# ***** (138/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.16629 at epoch 1
#
# ***** (139/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25443 at epoch 5
#
# ***** (140/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# SCORE: 1.25446 at epoch 12
#
# ***** (141/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99445 at epoch 9
#
# ***** (142/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.9947 at epoch 3
#
# ***** (143/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99584 at epoch 6
#
# ***** (144/216) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99719 at epoch 3
#
# ***** (145/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00679 at epoch 4
#
# ***** (146/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00045 at epoch 4
#
# ***** (147/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.0061 at epoch 4
#
# ***** (148/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00036 at epoch 3
#
# ***** (149/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 13.
# Epoch 18: early stopping
# SCORE: 1.0721 at epoch 13
#
# ***** (150/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.24058 at epoch 1
#
# ***** (151/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 1.08548 at epoch 9
#
# ***** (152/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.10431 at epoch 1
#
# ***** (153/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 0.9964 at epoch 9
#
# ***** (154/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99037 at epoch 3
#
# ***** (155/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 0.99673 at epoch 6
#
# ***** (156/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99436 at epoch 3
#
# ***** (157/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.0035 at epoch 4
#
# ***** (158/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00033 at epoch 3
#
# ***** (159/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00371 at epoch 4
#
# ***** (160/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00067 at epoch 3
#
# ***** (161/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.2544 at epoch 2
#
# ***** (162/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25326 at epoch 1
#
# ***** (163/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25443 at epoch 5
#
# ***** (164/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.08422 at epoch 1
#
# ***** (165/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 0.99636 at epoch 9
#
# ***** (166/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99208 at epoch 5
#
# ***** (167/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99666 at epoch 6
#
# ***** (168/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99431 at epoch 3
#
# ***** (169/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00208 at epoch 4
#
# ***** (170/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00097 at epoch 3
#
# ***** (171/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.00552 at epoch 2
#
# ***** (172/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00269 at epoch 3
#
# ***** (173/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 15.
# Epoch 20: early stopping
# SCORE: 1.13933 at epoch 15
#
# ***** (174/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.16998 at epoch 1
#
# ***** (175/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# SCORE: 1.04278 at epoch 10
#
# ***** (176/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.11068 at epoch 1
#
# ***** (177/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 0.99547 at epoch 9
#
# ***** (178/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99534 at epoch 3
#
# ***** (179/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99569 at epoch 9
#
# ***** (180/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99451 at epoch 3
#
# ***** (181/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00056 at epoch 3
#
# ***** (182/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.00534 at epoch 3
#
# ***** (183/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00729 at epoch 4
#
# ***** (184/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00546 at epoch 3
#
# ***** (185/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.2544 at epoch 2
#
# ***** (186/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25456 at epoch 5
#
# ***** (187/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25443 at epoch 5
#
# ***** (188/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.08274 at epoch 3
#
# ***** (189/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99544 at epoch 5
#
# ***** (190/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99436 at epoch 4
#
# ***** (191/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99539 at epoch 6
#
# ***** (192/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99137 at epoch 3
#
# ***** (193/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00081 at epoch 4
#
# ***** (194/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00083 at epoch 3
#
# ***** (195/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.01126 at epoch 4
#
# ***** (196/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00276 at epoch 3
#
# ***** (197/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# SCORE: 1.075 at epoch 11
#
# ***** (198/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25468 at epoch 1
#
# ***** (199/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.25442 at epoch 8
#
# ***** (200/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.04654 at epoch 1
#
# ***** (201/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99517 at epoch 5
#
# ***** (202/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99178 at epoch 4
#
# ***** (203/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 8.
# Epoch 13: early stopping
# SCORE: 0.99605 at epoch 8
#
# ***** (204/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 0.99961 at epoch 2
#
# ***** (205/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00089 at epoch 4
#
# ***** (206/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.00586 at epoch 3
#
# ***** (207/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00273 at epoch 4
#
# ***** (208/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.0001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00483 at epoch 3
#
# ***** (209/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25441 at epoch 2
#
# ***** (210/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.18896 at epoch 1
#
# ***** (211/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25443 at epoch 5
#
# ***** (212/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.01, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.18427 at epoch 2
#
# ***** (213/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99591 at epoch 5
#
# ***** (214/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 128, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99591 at epoch 3
#
# ***** (215/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'sigmoid'})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99627 at epoch 6
#
# ***** (216/216) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 120, 'max_units': 1200, 'lr': 0.001, 'epochs': 100, 'batch_size': 256, 'activation': 'relu'})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99354 at epoch 3

# %% [markdown]
# ### Best Model Found

# %%
best_params = kgs.best_params
print(best_params)
# Out:
# {'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 3, 'batch_size': 128, 'activation': 'relu', 'steps_per_epoch': 8276}

# %%
best_model = kgs.best_model
evaluation = best_model.evaluate(X_test, y_test, verbose=1)

best_score_rmse = math.sqrt(kgs.best_score)
print('Validation RMSE: ' + str(best_score_rmse))

best_model = get_model(best_params)
# Out:
# 3678/3678 [==============================] - 10s 3ms/step - loss: 0.9901 - root_mean_squared_error: 0.9950
# Validation RMSE: 0.9950175877842562

# %% [markdown]
# #### Training
# Best Model Found

# %%
best_model.fit(X, y,
               batch_size=best_params['batch_size'],
               epochs=best_params['epochs'],
               verbose="auto")
# Out:
# Epoch 1/3
# 9195/9195 [==============================] - 41s 4ms/step - loss: 1.0654 - root_mean_squared_error: 1.0322
# Epoch 2/3
# 9195/9195 [==============================] - 40s 4ms/step - loss: 0.9965 - root_mean_squared_error: 0.9982
# Epoch 3/3
# 9195/9195 [==============================] - 41s 4ms/step - loss: 0.9717 - root_mean_squared_error: 0.9857

# %% [markdown]
# #### Prediction
# Best Model Found

# %%
sub_pred = best_model.predict(X_sub)

# %% [markdown]
# #### Submission
# Best Model Found

# %%
submission_from_separate_predictions(sub_pd, sub_pred, sub_user_data, sub_movie_data, 'seedset_fulldata_neural_nets_best_model')
# Out:
#             Prediction
# Id
# r3092_c369    4.202448
# r3996_c315    3.683816
# r8787_c296    4.745072

# %% [markdown]
# ## Best Model (statically)

# %% [markdown]
# ### Training

# %%
best_params_static = {
    'user_embedding_size' : 40,
    'movie_embedding_size' : 40,
    'max_units' : 800,
    'lr' : 0.001,
    'epochs' : 3,
    'batch_size' : 128,
    'activation' : 'relu'
}
best_model_static = get_model(best_params_static)

# %%
best_model_static.fit(X, y,
                      batch_size=best_params_static['batch_size'],
                      epochs=best_params_static['epochs'],
                      verbose="auto")
# Out:
# Epoch 1/3
# 9195/9195 [==============================] - 42s 4ms/step - loss: 1.0681 - root_mean_squared_error: 1.0335
# Epoch 2/3
# 9195/9195 [==============================] - 42s 5ms/step - loss: 0.9961 - root_mean_squared_error: 0.9981
# Epoch 3/3
# 9195/9195 [==============================] - 41s 4ms/step - loss: 0.9685 - root_mean_squared_error: 0.9841

# %% [markdown]
# ### Prediction

# %%
sub_pred = best_model_static.predict(X_sub)

# %% [markdown]
# ### Submission

# %%
submission_from_separate_predictions(sub_pd, sub_pred, sub_user_data, sub_movie_data, 'seedset_fulldata_neural_nets_best_model_static')
# Out:
#             Prediction
# Id
# r7244_c61     3.730112
# r7489_c253    4.053943
# r3104_c457    4.327858
