# %% [markdown]
# # Neural Network for Collaborative Filtering

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install kaggle

# !mkdir ~/.kaggle

import json

kaggle_username = "yuvalnis" #@param {type:"string"}
kaggle_api_key = "1800d5a286834f0416c338c7bd7f6dee" #@param {type:"string"}

assert len(kaggle_username) > 0 and len(kaggle_api_key) > 0

api_token = {"username": kaggle_username,"key": kaggle_api_key}

with open('kaggle.json', 'w') as file:
    json.dump(api_token, file)

# !mv kaggle.json ~/.kaggle/kaggle.json

# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c cil-collaborative-filtering-2022

# !unzip -n cil-collaborative-filtering-2022.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.6.15)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# cil-collaborative-filtering-2022.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  cil-collaborative-filtering-2022.zip

# %%
#!pip install scikeras

# %%
# !pip install --upgrade keras-hypetune
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras-hypetune in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: hyperopt==0.2.5 in /usr/local/lib/python3.7/dist-packages (from keras-hypetune) (0.2.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-hypetune) (1.21.6)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (1.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (4.64.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (0.16.0)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (2.6.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt==0.2.5->keras-hypetune) (1.7.3)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

from keras.layers import Input, Embedding, Reshape, Dot, Concatenate, Dense, Dropout, Flatten, Lambda
from keras.models import Model

from keras.callbacks import *

# %tensorflow_version 2.x
import tensorflow as tf

#from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

#from scikeras.wrappers import KerasRegressor

from kerashypetune import *

# %%
print('TF VERSION = ' + str(tf.__version__))
# Out:
# TF VERSION = 2.8.2

# %% [markdown]
# ## Functions

# %%
def extract_users_items_predictions(data_pd):
        users, movies = \
            [np.squeeze(arr) for arr in np.split(data_pd.Id.str.extract('r(\d+)_c(\d+)').values.astype(int) - 1, 2, axis=-1)]
        predictions = data_pd.Prediction.values
        return users, movies, predictions

def submission_from_separate_predictions(sub_pd, sub_pred, sub_user_data, sub_movie_data, filename):
  temp_pd = sub_pd.copy()
  Id = []
  pred = []
  for i in range(sub_pred.shape[0]):
    Id.append("r"+str(sub_user_data[i]+1)+"_c"+str(sub_movie_data[i]+1))
    pred.append(sub_pred[i,0])
  temp_pd['Prediction'] = pred
  temp_pd.set_index("Id", inplace = True)
  print(temp_pd.sample(3)) 
  temp_pd.to_csv('drive/MyDrive/cil_data/sub/submission_'+str(filename)+'.csv')

# %% [markdown]
# ## Input

# %%
data_pd = pd.read_csv('data_train.csv')
tmp_users, tmp_movies, tmp_predictions = extract_users_items_predictions(data_pd)

d = {'User': tmp_users, 'Rating': tmp_predictions, 'Movie': tmp_movies}
df = pd.DataFrame(data=d)

del tmp_users, tmp_movies, tmp_predictions

df.sample(3)
# Out:
#         User  Rating  Movie
# 51099   3758       5     42
# 476228  1784       2    410
# 998571  9206       5    788

# %%
sub_pd = pd.read_csv('sampleSubmission.csv')#,index_col='Id')
tmp_users, tmp_movies, tmp_predictions = extract_users_items_predictions(sub_pd)

d = {'User': tmp_users, 'Rating': tmp_predictions, 'Movie': tmp_movies}
df_sub = pd.DataFrame(data=d)

del tmp_users, tmp_movies, tmp_predictions

sub_user_data = df_sub['User']
sub_movie_data = df_sub['Movie']

df_sub.sample(3)
# Out:
#          User  Rating  Movie
# 613933   4566       3    521
# 311041   9001       3    255
# 1078677  5627       3    875

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# ### Train-test split

# %%
df = df.reset_index(drop=True)

print(df.shape)

train_size = 0.85

from sklearn.model_selection import train_test_split

df_train, df_test = train_test_split(df, train_size=train_size, random_state=42)

print(df_train.shape)
print(df_test.shape)
# Out:
# (1176952, 3)
# (1000409, 3)
# (176543, 3)

# %% [markdown]
# ### Mapping to users/movies

# %%
user_id_mapping = {id:i for i, id in enumerate(df['User'].unique())}
movie_id_mapping = {id:i for i, id in enumerate(df['Movie'].unique())}

train_user_data = df_train['User'].map(user_id_mapping)
train_movie_data = df_train['Movie'].map(movie_id_mapping)

test_user_data = df_test['User'].map(user_id_mapping)
test_movie_data = df_test['Movie'].map(movie_id_mapping)

# Get input variable-sizes
users = len(user_id_mapping)
movies = len(movie_id_mapping)

print("Number of users: " + str(users))
print("Number of movies: " + str(movies))
# Out:
# Number of users: 10000
# Number of movies: 1000

# %%
train_user_data.to_numpy()
print("Train user data shape: " + str(train_user_data.shape))

train_movie_data.to_numpy()
print("Train movie data shape: " + str(train_movie_data.shape))

train_ratings_data = df_train[['Rating']].to_numpy()
print("Train ratings data shape: " + str(train_ratings_data.shape))

train_data = np.stack([train_user_data, train_movie_data], axis=-1)
print("Train data shape: " + str(train_data.shape))

test_user_data.to_numpy()
print("Test user data shape: " + str(test_user_data.shape))

test_movie_data.to_numpy()
print("Test movie data shape: " + str(test_movie_data.shape))

test_ratings_data = df_test[['Rating']].to_numpy()
print("Test ratings data shape: " + str(test_ratings_data.shape))

test_data = np.stack([test_user_data, test_movie_data], axis=-1)
print("Test data shape: " + str(test_data.shape))
# Out:
# Train user data shape: (1000409,)
# Train movie data shape: (1000409,)
# Train ratings data shape: (1000409, 1)
# Train data shape: (1000409, 2)
# Test user data shape: (176543,)
# Test movie data shape: (176543,)
# Test ratings data shape: (176543, 1)
# Test data shape: (176543, 2)

# %%
sub_user_data.to_numpy()
sub_movie_data.to_numpy()
sub_data = np.stack([sub_user_data, sub_movie_data], axis=-1)

# %% [markdown]
# ## Model

# %% [markdown]
# keras-hypetune

# %%
def get_model(param):
    combined_input = Input((2,))

    user_id_input = Lambda(lambda x: tf.expand_dims(x[:,0],-1))(combined_input)
    u = Embedding(input_dim=users, output_dim=param['user_embedding_size'], name="users_embedding")(user_id_input)
    u = Flatten()(u)

    movie_id_input = Lambda(lambda x: tf.expand_dims(x[:,1],-1))(combined_input)
    i = Embedding(input_dim=movies, output_dim=param['movie_embedding_size'], name="items_embedding")(movie_id_input)
    i = Flatten()(i)

    x = Concatenate(name="concatenated_vector")([i, u])

    for n in [1, 2, 4]:
      x = Dense(units=param['max_units']/n, activation="relu", kernel_initializer="glorot_normal",)(x)
      x = Dropout(0.2)(x)

    x = Dense(units=12, activation="relu", kernel_initializer="glorot_normal")(x)
    y = Dense(units=1)(x)


    model = Model(inputs=combined_input, outputs=y)
    model.compile(
        loss='mean_squared_error',
        optimizer=tf.keras.optimizers.Adam(learning_rate=param['lr']),
        metrics=[tf.keras.metrics.RootMeanSquaredError()],
    )
    
    return model

# %%
param_grid = {
    'user_embedding_size': [40, 80, 120, 160], 
    'movie_embedding_size': [20, 40, 60, 80],
    'max_units' : [800, 1600, 2400],
    'lr': [1e-2, 1e-3],
    'epochs': [100], 
    'batch_size': [128, 256, 512]
}

kgs = KerasGridSearch(get_model, param_grid, monitor='val_loss', store_model=True, greater_is_better=False, tuner_verbose=1)

es = EarlyStopping(patience=5, verbose=1, min_delta=0.001, monitor='val_loss', mode='auto', restore_best_weights=True)

# %%
kgs.search(train_data, train_ratings_data, validation_data=(test_data, test_ratings_data), callbacks=[es])
# Out:
# 288 trials detected for ('user_embedding_size', 'movie_embedding_size', 'max_units', 'lr', 'epochs', 'batch_size')
#
# ***** (1/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.08748 at epoch 2
#
# ***** (2/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.06465 at epoch 2
#
# ***** (3/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.02403 at epoch 1
#
# ***** (4/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.98988 at epoch 4
#
# ***** (5/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99615 at epoch 3
#
# ***** (6/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.02485 at epoch 1
#
# ***** (7/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.17548 at epoch 4
#
# ***** (8/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.05692 at epoch 3
#
# ***** (9/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.10438 at epoch 4
#
# ***** (10/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99248 at epoch 4
#
# ***** (11/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99277 at epoch 3
#
# ***** (12/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99435 at epoch 3
#
# ***** (13/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.15435 at epoch 1
#
# ***** (14/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.13925 at epoch 1
#
# ***** (15/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.25195 at epoch 3
#
# ***** (16/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99259 at epoch 4
#
# ***** (17/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.9953 at epoch 3
#
# ***** (18/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.9981 at epoch 3
#
# ***** (19/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.14101 at epoch 1
#
# ***** (20/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.03142 at epoch 1
#
# ***** (21/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.0388 at epoch 1
#
# ***** (22/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99204 at epoch 4
#
# ***** (23/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99172 at epoch 3
#
# ***** (24/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.01267 at epoch 1
#
# ***** (25/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# SCORE: 1.25194 at epoch 7
#
# ***** (26/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.14558 at epoch 1
#
# ***** (27/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.04109 at epoch 2
#
# ***** (28/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.9879 at epoch 4
#
# ***** (29/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99511 at epoch 3
#
# ***** (30/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00822 at epoch 3
#
# ***** (31/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25202 at epoch 3
#
# ***** (32/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.0775 at epoch 3
#
# ***** (33/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 8.
# Epoch 13: early stopping
# SCORE: 1.04567 at epoch 8
#
# ***** (34/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99266 at epoch 4
#
# ***** (35/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99341 at epoch 3
#
# ***** (36/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00331 at epoch 3
#
# ***** (37/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25189 at epoch 1
#
# ***** (38/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.04732 at epoch 1
#
# ***** (39/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.04101 at epoch 1
#
# ***** (40/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99712 at epoch 3
#
# ***** (41/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99306 at epoch 4
#
# ***** (42/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.9982 at epoch 3
#
# ***** (43/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25315 at epoch 4
#
# ***** (44/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.08917 at epoch 3
#
# ***** (45/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 9.
# Epoch 14: early stopping
# SCORE: 1.04807 at epoch 9
#
# ***** (46/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99442 at epoch 4
#
# ***** (47/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99473 at epoch 4
#
# ***** (48/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99951 at epoch 4
#
# ***** (49/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.22335 at epoch 2
#
# ***** (50/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.14424 at epoch 1
#
# ***** (51/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.049 at epoch 3
#
# ***** (52/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.9936 at epoch 4
#
# ***** (53/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00323 at epoch 4
#
# ***** (54/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99924 at epoch 4
#
# ***** (55/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.15121 at epoch 1
#
# ***** (56/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.07149 at epoch 3
#
# ***** (57/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.03169 at epoch 1
#
# ***** (58/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99332 at epoch 4
#
# ***** (59/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99404 at epoch 3
#
# ***** (60/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.0026 at epoch 2
#
# ***** (61/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25193 at epoch 2
#
# ***** (62/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 1.062 at epoch 6
#
# ***** (63/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.04189 at epoch 2
#
# ***** (64/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99296 at epoch 4
#
# ***** (65/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99451 at epoch 3
#
# ***** (66/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99698 at epoch 3
#
# ***** (67/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25197 at epoch 2
#
# ***** (68/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.15686 at epoch 2
#
# ***** (69/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25193 at epoch 3
#
# ***** (70/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99298 at epoch 4
#
# ***** (71/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99345 at epoch 3
#
# ***** (72/288) *****
# Search({'user_embedding_size': 40, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99572 at epoch 3
#
# ***** (73/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.1261 at epoch 2
#
# ***** (74/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.06873 at epoch 1
#
# ***** (75/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.04167 at epoch 1
#
# ***** (76/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99462 at epoch 4
#
# ***** (77/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99339 at epoch 3
#
# ***** (78/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99926 at epoch 4
#
# ***** (79/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.16258 at epoch 4
#
# ***** (80/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.08003 at epoch 4
#
# ***** (81/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.17922 at epoch 1
#
# ***** (82/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99178 at epoch 4
#
# ***** (83/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99413 at epoch 3
#
# ***** (84/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00042 at epoch 3
#
# ***** (85/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 1.25194 at epoch 8
#
# ***** (86/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.05378 at epoch 2
#
# ***** (87/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25216 at epoch 4
#
# ***** (88/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99175 at epoch 4
#
# ***** (89/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99676 at epoch 4
#
# ***** (90/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99739 at epoch 3
#
# ***** (91/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.17398 at epoch 1
#
# ***** (92/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.08473 at epoch 3
#
# ***** (93/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.01841 at epoch 1
#
# ***** (94/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99028 at epoch 3
#
# ***** (95/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.995 at epoch 3
#
# ***** (96/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.9938 at epoch 3
#
# ***** (97/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25196 at epoch 3
#
# ***** (98/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.08439 at epoch 3
#
# ***** (99/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.02846 at epoch 3
#
# ***** (100/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99296 at epoch 3
#
# ***** (101/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99041 at epoch 3
#
# ***** (102/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99626 at epoch 3
#
# ***** (103/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.08559 at epoch 1
#
# ***** (104/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25202 at epoch 5
#
# ***** (105/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25203 at epoch 2
#
# ***** (106/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99544 at epoch 4
#
# ***** (107/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99984 at epoch 3
#
# ***** (108/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00076 at epoch 3
#
# ***** (109/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.14237 at epoch 1
#
# ***** (110/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.05497 at epoch 4
#
# ***** (111/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.02126 at epoch 2
#
# ***** (112/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99423 at epoch 5
#
# ***** (113/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99475 at epoch 5
#
# ***** (114/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99757 at epoch 4
#
# ***** (115/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.16643 at epoch 1
#
# ***** (116/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.08118 at epoch 2
#
# ***** (117/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.17768 at epoch 1
#
# ***** (118/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.992 at epoch 5
#
# ***** (119/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.98944 at epoch 4
#
# ***** (120/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 1.00182 at epoch 5
#
# ***** (121/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.1189 at epoch 1
#
# ***** (122/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25204 at epoch 2
#
# ***** (123/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.14447 at epoch 1
#
# ***** (124/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.98838 at epoch 5
#
# ***** (125/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99198 at epoch 4
#
# ***** (126/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99894 at epoch 4
#
# ***** (127/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.252 at epoch 4
#
# ***** (128/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.07395 at epoch 3
#
# ***** (129/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.04393 at epoch 1
#
# ***** (130/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.98953 at epoch 4
#
# ***** (131/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99349 at epoch 3
#
# ***** (132/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.01694 at epoch 3
#
# ***** (133/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.18029 at epoch 1
#
# ***** (134/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.22398 at epoch 1
#
# ***** (135/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.0828 at epoch 2
#
# ***** (136/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99367 at epoch 5
#
# ***** (137/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99504 at epoch 4
#
# ***** (138/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99828 at epoch 3
#
# ***** (139/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.2524 at epoch 4
#
# ***** (140/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25239 at epoch 1
#
# ***** (141/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.01738 at epoch 2
#
# ***** (142/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99237 at epoch 3
#
# ***** (143/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.9937 at epoch 3
#
# ***** (144/288) *****
# Search({'user_embedding_size': 80, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99995 at epoch 3
#
# ***** (145/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# SCORE: 1.15973 at epoch 8
#
# ***** (146/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.07774 at epoch 1
#
# ***** (147/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.01912 at epoch 4
#
# ***** (148/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99113 at epoch 4
#
# ***** (149/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99253 at epoch 4
#
# ***** (150/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.03487 at epoch 1
#
# ***** (151/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.09184 at epoch 1
#
# ***** (152/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.22514 at epoch 1
#
# ***** (153/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25194 at epoch 4
#
# ***** (154/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99078 at epoch 5
#
# ***** (155/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99455 at epoch 3
#
# ***** (156/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00103 at epoch 4
#
# ***** (157/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.15151 at epoch 1
#
# ***** (158/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.25203 at epoch 7
#
# ***** (159/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.03467 at epoch 4
#
# ***** (160/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99139 at epoch 4
#
# ***** (161/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99623 at epoch 4
#
# ***** (162/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00557 at epoch 4
#
# ***** (163/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 8.
# Epoch 13: early stopping
# SCORE: 1.16584 at epoch 8
#
# ***** (164/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.05197 at epoch 1
#
# ***** (165/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.03204 at epoch 1
#
# ***** (166/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99465 at epoch 4
#
# ***** (167/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99295 at epoch 3
#
# ***** (168/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99712 at epoch 3
#
# ***** (169/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.14811 at epoch 1
#
# ***** (170/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25193 at epoch 4
#
# ***** (171/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25193 at epoch 1
#
# ***** (172/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99126 at epoch 4
#
# ***** (173/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.00096 at epoch 4
#
# ***** (174/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99289 at epoch 3
#
# ***** (175/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25193 at epoch 2
#
# ***** (176/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25194 at epoch 2
#
# ***** (177/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25193 at epoch 1
#
# ***** (178/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99632 at epoch 4
#
# ***** (179/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99082 at epoch 3
#
# ***** (180/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99643 at epoch 3
#
# ***** (181/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.16707 at epoch 1
#
# ***** (182/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.0936 at epoch 1
#
# ***** (183/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.02213 at epoch 2
#
# ***** (184/288) *****
# Search({'user_embedding_size': 120, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# ...
# Search({'user_embedding_size': 160, 'movie_embedding_size': 40, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99748 at epoch 3
#
# ***** (229/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.25193 at epoch 4
#
# ***** (230/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.25202 at epoch 3
#
# ***** (231/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.03886 at epoch 2
#
# ***** (232/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99212 at epoch 5
#
# ***** (233/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99818 at epoch 3
#
# ***** (234/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 40, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99856 at epoch 3
#
# ***** (235/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.17414 at epoch 1
#
# ***** (236/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.05824 at epoch 4
#
# ***** (237/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.03409 at epoch 1
#
# ***** (238/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99088 at epoch 4
#
# ***** (239/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99085 at epoch 4
#
# ***** (240/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99734 at epoch 4
#
# ***** (241/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.18322 at epoch 1
#
# ***** (242/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.20928 at epoch 1
#
# ***** (243/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 10.
# Epoch 15: early stopping
# SCORE: 1.07192 at epoch 10
#
# ***** (244/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.98926 at epoch 4
#
# ***** (245/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.98898 at epoch 3
#
# ***** (246/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99452 at epoch 3
#
# ***** (247/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.11564 at epoch 1
#
# ***** (248/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25193 at epoch 3
#
# ***** (249/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.25194 at epoch 8
#
# ***** (250/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99325 at epoch 4
#
# ***** (251/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99355 at epoch 3
#
# ***** (252/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 80, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99362 at epoch 3
#
# ***** (253/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.06521 at epoch 1
#
# ***** (254/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.06472 at epoch 3
#
# ***** (255/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.03608 at epoch 4
#
# ***** (256/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 7.
# Epoch 12: early stopping
# SCORE: 0.99658 at epoch 7
#
# ***** (257/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.9908 at epoch 5
#
# ***** (258/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.9919 at epoch 4
#
# ***** (259/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 1.25195 at epoch 4
#
# ***** (260/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.11653 at epoch 1
#
# ***** (261/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 1.05715 at epoch 5
#
# ***** (262/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 6.
# Epoch 11: early stopping
# SCORE: 0.99767 at epoch 6
#
# ***** (263/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99299 at epoch 5
#
# ***** (264/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99684 at epoch 4
#
# ***** (265/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25195 at epoch 2
#
# ***** (266/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25194 at epoch 2
#
# ***** (267/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 1.04706 at epoch 5
#
# ***** (268/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.9963 at epoch 7
#
# ***** (269/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99077 at epoch 5
#
# ***** (270/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 20, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99794 at epoch 4
#
# ***** (271/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 2.
# Epoch 7: early stopping
# SCORE: 1.18943 at epoch 2
#
# ***** (272/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.14428 at epoch 1
#
# ***** (273/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.03559 at epoch 1
#
# ***** (274/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99094 at epoch 5
#
# ***** (275/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99229 at epoch 4
#
# ***** (276/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 800, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.00838 at epoch 3
#
# ***** (277/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.18144 at epoch 3
#
# ***** (278/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.21372 at epoch 1
#
# ***** (279/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 8.
# Epoch 13: early stopping
# SCORE: 1.0395 at epoch 8
#
# ***** (280/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.99406 at epoch 5
#
# ***** (281/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 4.
# Epoch 9: early stopping
# SCORE: 0.99134 at epoch 4
#
# ***** (282/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 1600, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99179 at epoch 3
#
# ***** (283/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.14162 at epoch 1
#
# ***** (284/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 1.
# Epoch 6: early stopping
# SCORE: 1.25196 at epoch 4
#
# ***** (285/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.01, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 1.25193 at epoch 3
#
# ***** (286/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 128})
# Restoring model weights from the end of the best epoch: 5.
# Epoch 10: early stopping
# SCORE: 0.98957 at epoch 5
#
# ***** (287/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 256})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.9908 at epoch 4
#
# ***** (288/288) *****
# Search({'user_embedding_size': 160, 'movie_embedding_size': 60, 'max_units': 2400, 'lr': 0.001, 'epochs': 100, 'batch_size': 512})
# Restoring model weights from the end of the best epoch: 3.
# Epoch 8: early stopping
# SCORE: 0.99576 at epoch 3

# %%
print(kgs.best_params)
print('Best score MSE: ' + str(kgs.best_score))
# Out:
# {'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 4, 'batch_size': 128, 'steps_per_epoch': 7816}
# Best score: 0.9879

# %%
# Best params: {'user_embedding_size': 40, 'movie_embedding_size': 80, 'max_units': 1600, 'lr': 0.001, 'epochs': 4, 'batch_size': 128, 'steps_per_epoch': 7816}

# %%
best_model = kgs.best_model #kgs.folds_best_models['fold 1']

# %% [markdown]
# ## Test Set Evaluation

# %%
evaluation = best_model.evaluate(x=test_data, y=test_ratings_data, verbose=1)
# Out:
# 5517/5517 [==============================] - 20s 4ms/step - loss: 0.9879 - root_mean_squared_error: 0.9939

# %% [markdown]
# ## Prediction

# %%
sub_pred = best_model.predict(sub_data)

# %% [markdown]
# ## Submission

# %%
submission_from_separate_predictions(sub_pd, sub_pred, sub_user_data, sub_movie_data, 'neural_nets')
# Out:
#             Prediction
# Id
# r1005_c460    3.065896
# r9850_c440    3.993016
# r3372_c637    3.342212
